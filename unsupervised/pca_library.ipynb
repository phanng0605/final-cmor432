# %% [markdown]
# # Principal Component Analysis (PCA) with Scikit-Learn
#
# This notebook demonstrates dimensionality reduction using PCA from scikit-learn on the Wine dataset.

# %% [markdown]
# ## 1. Introduction
# We will reduce high-dimensional data to 2 principal components for visualization and analysis.

# %% [markdown]
# ## 2. Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_wine
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import explained_variance_score

# %% [markdown]
# ## 3. Load and Prepare Data

# %%
# Load Wine dataset
wine = load_wine(as_frame=True)
X = wine.data
y = wine.target

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## 4. Apply PCA

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Explained variance
explained_var = pca.explained_variance_ratio_
print(f"Explained variance by PC1 and PC2: {explained_var}")
# Out:
# Explained variance by PC1 and PC2: [0.36198848 0.1920749 ]

# %% [markdown]
# ## 5. Visualization

# %%
plt.figure(figsize=(8,5))
for target in np.unique(y):
    plt.scatter(
        X_pca[y == target, 0], X_pca[y == target, 1],
        label=wine.target_names[target]
    )
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Wine Dataset')
plt.legend()
plt.show()

# %% [markdown]
# ## 6. Explained Variance Bar Chart (Optional)

# %%
plt.figure(figsize=(8,5))
plt.bar([1, 2], explained_var)
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.title('Explained Variance by Component')
plt.show()

# %% [markdown]
# ## 7. Conclusion
# PCA reduced the dataset to two dimensions, capturing most variance. Use additional components for reconstruction or analysis.
